# %%
SBD_1 = {
    "outline_coords": [(0,0), (300,0), (300,300), (0,300)],
    "reinforcement": {
        "grade": "B500B",
        "model_type": "horizontal",
        "gamma_s": 1.15,
        "gamma_s_accidental": 1.0,
        "E_s": 200_000,
        "layout": [
            (150, 150, 20.0)
        ],
    },
    "concrete": {
        "grade": "C45/55",
        "model_type": "parabola_rectangle",
        "alpha_cc": 0.85,
        "alpha_ct": 1.0,
        "gamma_c": 1.5,
        "gamma_c_accidental": 1.2,
    },
    "tolerance": 200.0,
    "analyses": {
        "type": "interaction_diagram",
        "limit_state": "ULS_PT",
        "results": [
            (0, 2423.5799),
            (0.2450811, 2406.3747),
            (6.0183477, 2375.9142),
            (9.3443281, 2345.4538),
            (12.744459, 2314.9933),
            (15.713973, 2284.5329),
            (18.817499, 2254.0725),
            (21.733372, 2223.612),
            (24.655723, 2193.1516),
            (27.569387, 2162.6911),
            (30.477815, 2132.2307),
            (33.380569, 2101.7703),
            (36.269841, 2071.3098),
            (39.150456, 2040.8494),
            (42.023139, 2010.389),
            (44.888684, 1979.9285),
            (47.732915, 1949.4681),
            (50.435231, 1919.0076),
            (53.091249, 1888.5472),
            (55.633994, 1858.0868),
            (58.062155, 1827.6263),
            (60.376125, 1797.1659),
            (62.576362, 1766.7054),
            (64.663356, 1736.245),
            (66.63762, 1705.7846),
            (68.499698, 1675.3241),
            (70.250162, 1644.8637),
            (71.889617, 1614.4033),
            (73.418704, 1583.9428),
            (74.838099, 1553.4824),
            (76.148517, 1523.0219),
            (77.350715, 1492.5615),
            (78.445493, 1462.1011),
            (79.433698, 1431.6406),
            (80.316226, 1401.1802),
            (81.094026, 1370.7197),
            (81.768103, 1340.2593),
            (82.339522, 1309.7989),
            (82.809409, 1279.3384),
            (83.178958, 1248.878),
            (83.449432, 1218.4175),
            (83.622169, 1187.9571),
            (83.698587, 1157.4967),
            (83.680185, 1127.0362),
            (83.568549, 1096.5758),
            (83.365358, 1066.1154),
            (83.072385, 1035.6549),
            (82.691505, 1005.1945),
            (82.224695, 974.73404),
            (81.674042, 944.2736),
            (81.041745, 913.81316),
            (80.357561, 883.35272),
            (79.59596, 852.89228),
            (78.766221, 822.43185),
            (77.87186, 791.97141),
            (76.916281, 761.51097),
            (75.903028, 731.05053),
            (74.835793, 700.59009),
            (73.718409, 670.12965),
            (72.55484, 639.66921),
            (71.349172, 609.20877),
            (70.1056, 578.74834),
            (68.828404, 548.2879),
            (67.521936, 517.82746),
            (66.190595, 487.36702),
            (64.838799, 456.90658),
            (63.153589, 426.44614),
            (60.943625, 395.9857),
            (58.518314, 365.52526),
            (55.96089, 335.06483),
            (53.09867, 304.60439),
            (50.454083, 274.14395),
            (47.324079, 243.68351),
            (44.249337, 213.22307),
            (41.049912, 182.76263),
            (37.725781, 152.30219),
            (34.280007, 121.84175),
            (30.704247, 91.381316),
            (27.007452, 60.920877),
            (19.361407, 0),
            (18.469938, -6.829549),
            (17.480911, -13.6591),
            (16.551153, -20.48865),
            (15.648264, -27.3182),
            (14.699495, -34.14775),
            (13.768365, -40.9773),
            (12.865892, -47.80684),
            (11.896415, -54.63639),
            (10.947993, -61.46594),
            (10.022768, -68.29549),
            (9.0325754, -75.12504),
            (8.1611177, -81.95459),
            (7.0839823, -88.78414),
            (6.1024575, -95.61369),
            (5.2207823, -102.4432),
            (4.1574934, -109.2728),
            (3.1874213, -116.1023),
            (2.1249476, -121.9682),
            (1.0624738, -127.8341),
            (0, -133.6999)
        ],
    },  
}

# %%
import json
from pathlib import Path
from typing import Any


def save_dict_to_json(data: dict[str, Any], filepath: str | Path) -> None:
    """
    Save a dictionary to a JSON file.

    Args:
        data: Dictionary to serialize.
        filepath: Path to output JSON file.
    """
    path = Path(filepath)
    path.parent.mkdir(parents=True, exist_ok=True)

    with path.open("w", encoding="utf-8") as f:
        json.dump(data, f, indent=2)


save_dict_to_json(
    SBD_1,
    filepath=r"C:\Users\user\Repo\Scripts\section_design_checks\benchmarks\sbd_2.json",
)
